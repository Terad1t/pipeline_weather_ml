# %%
path = '../data/weather_data.json'

import pandas as pd
import json

# %%
with open(path) as f:
    data = json.load(f)

df = pd.json_normalize(data)
df.head()
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 802, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id       name  cod  coord.lon  coord.lat  ...  \
# 0  1773438407    -10800  3448439  São Paulo  200   -46.6361   -23.5475  ...
#
#    main.sea_level  main.grnd_level  wind.speed  wind.deg  clouds.all  \
# 0            1012              922        5.14       160          40
#
#    sys.type  sys.id  sys.country  sys.sunrise  sys.sunset
# 0         1    8394           BR   1773392845  1773437089
#
# [1 rows x 26 columns]
